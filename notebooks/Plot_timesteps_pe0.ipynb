# %%
# A notebook to interrogate the timestep data from a pe0 log.
import pandas as pd
import sys
import io
from pathlib import Path
import numpy as np

# %%
PE_DIR=Path('/home/548/pag548/cylc-run/u-dq126/work/20220226T0000Z/Flagship_ERA5to1km_1km_RAL3P2_um_fcst_000/pe_output')

# %%
pe0_file = PE_DIR / 'umnsa.fort6.pe0'

# %%
csv_start = io.StringIO()
csv_elapsed = io.StringIO()
csv_start_lines = []
csv_elapsed_lines = []

with open(pe0_file, 'r') as fp:
    for index, line in enumerate(fp):
        if 'Atm_Step: Info: Starting' in line:
            csv_start_lines.append(f'{line}')
        if 'Atm_Step: Info: timestep' in line:
            csv_elapsed_lines.append(f'{line}')

# %%
for line in csv_start_lines:
    csv_start.write(line)

for line in csv_elapsed_lines:
    csv_elapsed.write(line)

# %%
csv_start.seek(0)
df_start = pd.read_csv(csv_start, header=None,sep='\s+')

# %%
df_start
# Out:
#              0      1         2         3    4   5      6        7        8
# 0    Atm_Step:  Info:  Starting  timestep    0  at  time=    9.973  seconds
# 1    Atm_Step:  Info:  Starting  timestep    1  at  time=   10.212  seconds
# 2    Atm_Step:  Info:  Starting  timestep    2  at  time=   17.564  seconds
# 3    Atm_Step:  Info:  Starting  timestep    3  at  time=   19.642  seconds
# 4    Atm_Step:  Info:  Starting  timestep    4  at  time=   21.705  seconds
# ..         ...    ...       ...       ...  ...  ..    ...      ...      ...
# 356  Atm_Step:  Info:  Starting  timestep  356  at  time=  773.214  seconds
# 357  Atm_Step:  Info:  Starting  timestep  357  at  time=  775.192  seconds
# 358  Atm_Step:  Info:  Starting  timestep  358  at  time=  777.068  seconds
# 359  Atm_Step:  Info:  Starting  timestep  359  at  time=  778.857  seconds
# 360  Atm_Step:  Info:  Starting  timestep  360  at  time=  780.619  seconds
#
# [361 rows x 9 columns]

# %%
csv_elapsed.seek(0)
df_elapsed = pd.read_csv(csv_elapsed, header=None,sep='\s+')

# %%
df_elapsed
# Out:
#              0      1         2    3     4      5        6
# 0    Atm_Step:  Info:  timestep    1  took  7.352  seconds
# 1    Atm_Step:  Info:  timestep    2  took  2.077  seconds
# 2    Atm_Step:  Info:  timestep    3  took  2.062  seconds
# 3    Atm_Step:  Info:  timestep    4  took  1.981  seconds
# 4    Atm_Step:  Info:  timestep    5  took  1.906  seconds
# ..         ...    ...       ...  ...   ...    ...      ...
# 355  Atm_Step:  Info:  timestep  356  took  1.978  seconds
# 356  Atm_Step:  Info:  timestep  357  took  1.875  seconds
# 357  Atm_Step:  Info:  timestep  358  took  1.788  seconds
# 358  Atm_Step:  Info:  timestep  359  took  1.762  seconds
# 359  Atm_Step:  Info:  timestep  360  took  5.945  seconds
#
# [360 rows x 7 columns]

# %%
df_elapsed.rename(columns={"5": "seconds"},inplace=True)

# %%
import matplotlib.pyplot as plt
fix,ax=plt.subplots(1,1)
df_elapsed.iloc[:,5].plot(ax=ax,xticks=np.arange(0,370,60),title="Flagship 1km seconds per timestep",xlabel='Timestep',ylabel='Seconds')
plt.savefig('Flagship_1km_Timesteps.png')

# %%
AUS_2200_PE_DIR=Path('/g/data/gb02/pag548/aus2200/work/20160605T0500Z/aus2200_d0198_RA3_um_fcst_000/pe_output')

# %%
pe0_file = AUS_2200_PE_DIR / 'umnsa.fort6.pe0'

# %%
csv_start = io.StringIO()
csv_elapsed = io.StringIO()
csv_start_lines = []
csv_elapsed_lines = []

with open(pe0_file, 'r') as fp:
    for index, line in enumerate(fp):
        if 'Atm_Step: Info: Starting' in line:
            csv_start_lines.append(f'{line}')
        if 'Atm_Step: Info: timestep' in line:
            csv_elapsed_lines.append(f'{line}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 6
#       3 csv_start_lines = []
#       4 csv_elapsed_lines = []
# ----> 6 with open(pe0_file, 'r') as fp:
#       7     for index, line in enumerate(fp):
#       8         if 'Atm_Step: Info: Starting' in line:
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.03/lib/python3.11/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/g/data/gb02/pag548/aus2200/work/20160605T0500Z/aus2200_d0198_RA3_um_fcst_000/pe_output/umnsa.fort6.pe0'

# %%
for line in csv_start_lines:
    csv_start.write(line)

for line in csv_elapsed_lines:
    csv_elapsed.write(line)

# %%
csv_start.seek(0)
df_start = pd.read_csv(csv_start, header=None,sep='\s+')

# %%
csv_elapsed.seek(0)
df_elapsed = pd.read_csv(csv_elapsed, header=None,sep='\s+')

# %%
df_elapsed.rename(columns={"5": "seconds"},inplace=True)

# %%
fix,ax=plt.subplots(1,1)
df_elapsed.iloc[:,5].plot(ax=ax,xticks=np.arange(0,300,75),title="AUS2200 seconds per timestep",xlabel='Timestep',ylabel='Seconds')
plt.savefig('AUS2200_1km_Timesteps.png')

# %%
df_start
# Out:
#              0      1         2         3    4   5      6        7        8
# 0    Atm_Step:  Info:  Starting  timestep    0  at  time=   39.865  seconds
# 1    Atm_Step:  Info:  Starting  timestep    1  at  time=   40.457  seconds
# 2    Atm_Step:  Info:  Starting  timestep    2  at  time=   47.645  seconds
# 3    Atm_Step:  Info:  Starting  timestep    3  at  time=   48.862  seconds
# 4    Atm_Step:  Info:  Starting  timestep    4  at  time=   49.882  seconds
# ..         ...    ...       ...       ...  ...  ..    ...      ...      ...
# 284  Atm_Step:  Info:  Starting  timestep  284  at  time=  404.855  seconds
# 285  Atm_Step:  Info:  Starting  timestep  285  at  time=  406.209  seconds
# 286  Atm_Step:  Info:  Starting  timestep  286  at  time=  407.257  seconds
# 287  Atm_Step:  Info:  Starting  timestep  287  at  time=  408.258  seconds
# 288  Atm_Step:  Info:  Starting  timestep  288  at  time=  409.646  seconds
#
# [289 rows x 9 columns]

# %%
PE_DIR=Path('/home/548/pag548/cylc-run/21CW-access-am3-configs/work/20070101T0000Z/atmos_main/pe_output')

# %%
pe0_file = PE_DIR / 'acces.fort6.pe0000'

# %%
csv_start = io.StringIO()
csv_elapsed = io.StringIO()
csv_start_lines = []
csv_elapsed_lines = []

with open(pe0_file, 'r') as fp:
    for index, line in enumerate(fp):
        if 'Atm_Step: Info: Starting' in line:
            csv_start_lines.append(f'{line}')
        if 'Atm_Step: Info: timestep' in line:
            csv_elapsed_lines.append(f'{line}')

# %%
for line in csv_start_lines:
    csv_start.write(line)

for line in csv_elapsed_lines:
    csv_elapsed.write(line)

# %%
csv_start.seek(0)
df_start = pd.read_csv(csv_start, header=None,sep='\s+')

# %%
csv_elapsed.seek(0)
df_elapsed = pd.read_csv(csv_elapsed, header=None,sep='\s+')

# %%
df_elapsed.rename(columns={"5": "seconds"},inplace=True)

# %%
import matplotlib.pyplot as plt
fig,ax=plt.subplots(1,1,figsize=(15,6))
df_elapsed.iloc[:,5].plot(ax=ax,xticks=np.arange(0,900,100),title="AM3_N512 seconds per timestep",xlabel='Timestep',ylabel='Seconds')
ax.set_xlim([0,800])
plt.savefig('AM3_N512_Sapphirerapids_Timesteps.png')

# %%
fig,ax=plt.subplots(1,1,figsize=(15,6))
df_elapsed.iloc[:,5][:360].plot(ax=ax,xticks=np.arange(0,400,50),title="AM3_N512 seconds per timestep",xlabel='Timestep',ylabel='Seconds')
ax.set_xlim([0,360])
# Out:
# (0.0, 360.0)

# %%
df_elapsed[:20]
# Out:
#             0      1         2   3     4      5        6
# 0   Atm_Step:  Info:  timestep   1  took  4.228  seconds
# 1   Atm_Step:  Info:  timestep   2  took  1.267  seconds
# 2   Atm_Step:  Info:  timestep   3  took  1.268  seconds
# 3   Atm_Step:  Info:  timestep   4  took  1.274  seconds
# 4   Atm_Step:  Info:  timestep   5  took  1.275  seconds
# 5   Atm_Step:  Info:  timestep   6  took  1.277  seconds
# 6   Atm_Step:  Info:  timestep   7  took  3.910  seconds
# 7   Atm_Step:  Info:  timestep   8  took  1.315  seconds
# 8   Atm_Step:  Info:  timestep   9  took  1.322  seconds
# 9   Atm_Step:  Info:  timestep  10  took  1.351  seconds
# 10  Atm_Step:  Info:  timestep  11  took  2.228  seconds
# 11  Atm_Step:  Info:  timestep  12  took  1.307  seconds
# 12  Atm_Step:  Info:  timestep  13  took  3.977  seconds
# 13  Atm_Step:  Info:  timestep  14  took  1.327  seconds
# 14  Atm_Step:  Info:  timestep  15  took  1.347  seconds
# 15  Atm_Step:  Info:  timestep  16  took  1.325  seconds
# 16  Atm_Step:  Info:  timestep  17  took  1.503  seconds
# 17  Atm_Step:  Info:  timestep  18  took  1.989  seconds
# 18  Atm_Step:  Info:  timestep  19  took  3.927  seconds
# 19  Atm_Step:  Info:  timestep  20  took  1.338  seconds

# %%
df_elapsed.iloc[:,5][:360]
# Out:
# 0      4.228
# 1      1.267
# 2      1.268
# 3      1.274
# 4      1.275
#        ...
# 355    1.289
# 356    1.293
# 357    1.287
# 358    1.297
# 359    7.112
# Name: 5, Length: 360, dtype: float64
